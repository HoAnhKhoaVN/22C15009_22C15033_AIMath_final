# %%
import matplotlib.pyplot as plt
import seaborn as sns
from dataset import IrisDataset
from config import LINK_DATA_IRIS

# %% [markdown]
# # Get data

# %%
iris_ds = IrisDataset(link = LINK_DATA_IRIS)
iris_ds.train_df.head()
# Out:
# Size train have 70 records
# Size test have 30 records
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 32    33            5.2           4.1            1.5           0.1
# 6      7            4.6           3.4            1.4           0.3
# 3      4            4.6           3.1            1.5           0.2
# 12    13            4.8           3.0            1.4           0.1
# 101  102            5.8           2.7            5.1           1.9
#
#             Species
# 32      Iris-setosa
# 6       Iris-setosa
# 3       Iris-setosa
# 12      Iris-setosa
# 101  Iris-virginica

# %%
iris_ds.test_df.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
iris_ds.val_df.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 123  124            6.3           2.7            4.9           1.8
# 85    86            6.0           3.4            4.5           1.6
# 113  114            5.7           2.5            5.0           2.0
# 129  130            7.2           3.0            5.8           1.6
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 123   Iris-virginica
# 85   Iris-versicolor
# 113   Iris-virginica
# 129   Iris-virginica
# 149   Iris-virginica

# %% [markdown]
# # Visulization data

# %%
plt.figure(figsize=(5,5))
plt.plot(['PetalLengthCm'])
plt.title('PETAL LENGTH IN CM')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data = iris_ds.train_df,marker='s', hue='Species')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=iris_ds.train_df,marker='s', hue='Species')
plt.show()

# %%
x = sns.pairplot(data= iris_ds.train_df.drop(columns=['Id']), hue="Species")

# %%
x.savefig("pairplot.png")

# %%
sns.jointplot(data=iris_ds.train_df, x="SepalLengthCm", y="SepalWidthCm", hue="Species")

# %%
iris_ds.train_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
